# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('career_pred.csv')

# Select the columns for the scatter plot
x = df.iloc[:,:25]
x
# Out:
#       sslc  hsc  cgpa  school_type  no_of_miniprojects  no_of_projects  \
# 0        2    3     2            3                   1               1
# 1        3    1     2            2                   2               1
# 2        3    4     2            2                   1               1
# 3        3    4     2            1                   1               1
# 4        2    3     2            4                   1               1
# ...    ...  ...   ...          ...                 ...             ...
# 7520     3    2     1            2                   1               1
# 7521     2    3     3            3                   4               3
# 7522     3    2     1            2                   1               1
# 7523     2    1     1            1                   2               1
# 7524     2    2     2            3                   2               1
#
#       coresub_skill  aptitude_skill  problemsolving_skill  programming_skill  \
# ...

# %%
y = df.iloc[:,25]
len(y.unique())
# Out:
# 9

# %%
filtered_df = df.loc[df['learning_style'] == 'high']
if not filtered_df.empty:
    df.loc[df['learning_style'] == 'high', 'learning_style'] = 4
filtered_df
# Out:
#       sslc  hsc  cgpa  school_type  no_of_miniprojects  no_of_projects  \
# 1261     3    3     4            3                   2               1
# 3781     4    4     4            1                   1               1
#
#       coresub_skill  aptitude_skill  problemsolving_skill  programming_skill  \
# 1261              2               1                     4                  1
# 3781              2               1                     4                  1
#
#       ...  technology_used  sympos_attend  sympos_won  extracurricular  \
# 1261  ...                1              3           1                4
# 3781  ...                1              4           2                4
#
#       learning_style  college_bench  clg_teachers_know  college_performence   \
# 1261            high              4                  4                     4
# 3781            high              4                  4                     4
#
#       college_skills  ROLE
# 1261               2   NaN
# ...

# %%
#filtering the data

def update_column(df, column, filter_value, replacement_value):
    filtered_df = df.loc[df[column] == filter_value]
    if not filtered_df.empty:
        df.loc[df[column] == filter_value, column] = replacement_value

        
update_column(df,'learning_style','high',4)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame called 'df'

# Select the column you want to plot
column_name = 'sslc'

# Plot the column as a bar plot
df.iloc[:,1].value_counts().plot.bar()

# Set the labels and title
plt.xlabel(column_name)
plt.ylabel('Count')
plt.title(f'Bar Plot of {column_name}')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming your dataset is stored in a DataFrame called 'df'
# Specify the columns you want to plot
columns_to_plot = ['sslc', 'hsc', 'cgpa']

# Define a color palette for the bars
color_palette = ['red', 'blue', 'green']

# Create a figure and axis object
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 0.2

# Calculate the offset for each bar
offset = np.arange(len(columns_to_plot)) * bar_width

# Iterate over the columns
for i, column in enumerate(columns_to_plot):
    # Create a bar plot for each column with different colors
    df[column].value_counts().sort_index().plot.bar(ax=ax, label=column, color=color_palette[i],
                                                    width=bar_width, position=i)

# Set the x-axis labels and tick positions
ax.set_xticks(offset + (bar_width * len(columns_to_plot) / 2))
ax.set_xticklabels(columns_to_plot)

# Set the labels and title
ax.set_xlabel('X-axis label')
ax.set_ylabel('Y-axis label')
ax.set_title('Bar Plot of Multiple Columns')

# Set the legend
ax.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame called 'df'
# Specify the columns you want to plot
columns_to_plot = ['sslc', 'hsc', 'cgpa']

# Define a color palette for the bars
color_palette = ['red', 'blue', 'green']

# Create a figure and axis object
fig, ax = plt.subplots()

# Iterate over the columns
for i, column in enumerate(columns_to_plot):
    # Create a bar plot for each column with different colors
    df[column].value_counts().sort_index().plot.bar(ax=ax, label=column, color=color_palette[i])

# Set the labels and title
ax.set_xlabel('X-axis label')
ax.set_ylabel('Y-axis label')
ax.set_title('Bar Plot of Multiple Columns')

# Set the legend
ax.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming your dataset is stored in a DataFrame called 'df'

# Get the list of column names
columns_to_plot = df.columns.tolist()

# Define a color palette for the bars
color_palette = plt.cm.Set3(np.linspace(0, 1, len(columns_to_plot)))

# Create a figure and axis object
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 4 / len(columns_to_plot)

# Calculate the offset for each bar
offset = np.arange(len(columns_to_plot)) * bar_width

# Iterate over the columns
for i, column in enumerate(columns_to_plot):
    # Create a bar plot for each column with different colors
    df[column].value_counts().sort_index().plot.bar(ax=ax, label=column, color=color_palette[i],
                                                    width=bar_width, position=i*bar_width)

# Set the x-axis labels and tick positions
ax.set_xticks(offset + (bar_width * len(columns_to_plot) / 2))
ax.set_xticklabels(columns_to_plot, rotation=90)

# Set the labels and title
ax.set_xlabel('Columns')
ax.set_ylabel('Count')
ax.set_title('Bar Plot of Multiple Columns')

# Set the legend
ax.legend()

# Adjust the plot layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 25
#      22 # Iterate over the columns
#      23 for i, column in enumerate(columns_to_plot):
#      24     # Create a bar plot for each column with different colors
# ---> 25     df[column].value_counts().sort_index().plot.bar(ax=ax, label=column, color=color_palette[i],
#      26                                                     width=bar_width, position=i*bar_width)
#      28 # Set the x-axis labels and tick positions
#      29 ax.set_xticks(offset + (bar_width * len(columns_to_plot) / 2))
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming your dataset is stored in a DataFrame called 'df'

# Get the list of column names
columns_to_plot = df.columns.tolist()

# Define a color palette for the bars
color_palette = plt.cm.Set3(np.linspace(0, 1, len(columns_to_plot)))

# Create a figure and axis object
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 8 / len(columns_to_plot)

# Calculate the offset for each bar
offset = np.arange(len(columns_to_plot)) * bar_width

# Iterate over the columns
for i, column in enumerate(columns_to_plot):
    # Create a bar plot for each column with different colors
    df[column].value_counts().sort_index().plot.bar(ax=ax, label=column, color=color_palette[i],
                                                    width=bar_width, position=i*bar_width)

    # Calculate the mean value for the column
    mean_value = df[column].mean()
    
    # Add a marker for the mean value
    ax.plot(i*bar_width + bar_width/2, mean_value, marker='o', color='black', markersize=5)

# Set the x-axis labels and tick positions
ax.set_xticks(offset + (bar_width * len(columns_to_plot) / 2))
ax.set_xticklabels(columns_to_plot, rotation=90)

# Set the labels and title
ax.set_xlabel('Columns')
ax.set_ylabel('Count')
ax.set_title('Bar Plot of Multiple Columns')

# Set the legend
ax.legend()

# Add lines connecting the mean points
for i, column in enumerate(columns_to_plot[:-1]):
    x1 = i * bar_width + bar_width/2
    y1 = df[column].mean()
    x2 = (i+1) * bar_width + bar_width/2
    y2 = df[columns_to_plot[i+1]].mean()
    ax.plot([x1, x2], [y1, y2], 'k--')

# Adjust the plot layout
plt.tight_layout()

# Save the plot as a high-resolution image
plt.savefig('bar_plot.png', dpi=300)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 25
#      22 # Iterate over the columns
#      23 for i, column in enumerate(columns_to_plot):
#      24     # Create a bar plot for each column with different colors
# ---> 25     df[column].value_counts().sort_index().plot.bar(ax=ax, label=column, color=color_palette[i],
#      26                                                     width=bar_width, position=i*bar_width)
#      28     # Calculate the mean value for the column
#      29     mean_value = df[column].mean()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
import numpy as np
import pandas as pd

# Assuming you have a dataset stored in a CSV file
dataset_path = 'career_pred.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(dataset_path)

# Extract the "sslc" column data as a NumPy array
column_data = df['sslc'].values


# Calculate the unique values and their frequencies
values, counts = np.unique(column_data, return_counts=True)

# Create the bar chart
plt.bar(counts, values)

# Set the labels and title
plt.xlabel('Values')
plt.ylabel('Count')
plt.title('Bar Chart of SSLC')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a dataset stored in a CSV file
dataset_path = 'career_pred.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(dataset_path)

# Extract the column data
column_name = 'sslc'  # Replace 'column_name' with the actual column name in your dataset
column_data = df[column_name]




# Calculate the unique values and their frequencies
values, counts = np.unique(column_data, return_counts=True)

# Create an array to store the heights of the bars
bar_heights = [counts[np.where(values == value)][0] for value in column_data]

# Create the bar chart with custom heights
plt.bar(range(len(column_data)), bar_heights)

# Set the labels and title
plt.xlabel('Index')
plt.ylabel('Height')
plt.title('Bar Chart with Custom Heights')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the hypothetical array
array_length = 100
array_values = np.random.randint(1, 5, size=array_length)

# Calculate the unique values and their frequencies
values, counts = np.unique(array_values, return_counts=True)

# Create the bar chart
plt.bar(values, counts)

# Set the labels and title
plt.xlabel('Count')
plt.ylabel('Values')
plt.title('Bar Chart of Array')

# Display the chart
plt.show()
