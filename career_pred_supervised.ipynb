# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import PolynomialFeatures
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("career_pred.csv")
df
# Out:
#       sslc  hsc  cgpa  school_type  no_of_miniprojects  no_of_projects  \
# 0        2    3     2            3                   1               1
# 1        3    1     2            2                   2               1
# 2        3    4     2            2                   1               1
# 3        3    4     2            1                   1               1
# 4        2    3     2            4                   1               1
# ...    ...  ...   ...          ...                 ...             ...
# 7520     3    2     1            2                   1               1
# 7521     2    3     3            3                   4               3
# 7522     3    2     1            2                   1               1
# 7523     2    1     1            1                   2               1
# 7524     2    2     2            3                   2               1
#
#       coresub_skill  aptitude_skill  problemsolving_skill  programming_skill  \
# ...

# %%
#filtering the data

def update_column(df, column, filter_value, replacement_value):
    filtered_df = df.loc[df[column] == filter_value]
    if not filtered_df.empty:
        df.loc[df[column] == filter_value, column] = replacement_value

        
update_column(df,'learning_style','high',4)

df.loc[1261,'learning_style']="4"
df.loc[3781,'learning_style']='4'
df['learning_style'].value_counts()
# Out:
# 2    3197
# 1    1774
# 3    1428
# 4    1126
# Name: learning_style, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

data = df
# Separate the features (X) and the target variable (y)
X = data.drop('ROLE', axis=1)
X= X.iloc[:50,:]
X
y = data['ROLE']

# Encode the target variable to numerical values
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Create and train the logistic regression model
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

# Evaluate the model
accuracy = logreg.score(X_test, y_test)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 18
#      15 y = label_encoder.fit_transform(y)
#      17 # Split the data into training and testing sets
# ---> 18 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
#      20 # Create and train the logistic regression model
#      21 logreg = LogisticRegression()
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# Separate the features (X) and the target variable (y)
X = df.drop('ROLE', axis=1).iloc[:50, :]
y = df['ROLE'].iloc[:50]

# Encode the target variable to numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Create and train the logistic regression model
logreg = LogisticRegression()
logreg.fit(X, y_encoded)

# Example row of data for prediction
row_index = 0
row_data = X.iloc[row_index, :]

# Reshape the row data into a 2D array
X_pred = row_data.values.reshape(1, -1)

# Make predictions on the new data
predicted_label = logreg.predict(X_pred)

# Convert the numerical label back to the corresponding string value
predicted_role = label_encoder.inverse_transform(predicted_label)

# Print the predicted role
print("Predicted Role:", predicted_role)
# Out:
# Predicted Role: ['Technical Support']
# C:\Users\Afnan Qasim\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Afnan Qasim\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
